# %% [markdown]
# # VISHNU C
# # START TECH ACADEMY
# # TOPIC 2

# %%
# Question:
     Your task is to help John from STA IT services to create a linear regression model in Python or R to predict the CTC/Salary of new hires from the data provided.
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_18408/991020330.py", line 2
#     Your task is to help John from STA IT services to create a linear regression model in Python or R to predict the CTC/Salary of new hires from the data provided.
#     ^
# IndentationError: unexpected indent

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn import linear_model
import seaborn as sea

# %%
# Loading and scanning dataset
dataset = pd.read_csv('Data_file.xlsx - Data.csv', header = 2,index_col=0)
dataset
# Out:
#       College       Role  City type  Previous CTC  Previous job changes  \
# S.No.
# 1      Tier 1    Manager  Non-Metro    55,523.00                      3
# 2      Tier 2  Executive      Metro    57,081.00                      1
# 3      Tier 2  Executive      Metro    60,347.00                      2
# 4      Tier 3  Executive      Metro    49,010.00                      2
# 5      Tier 3  Executive      Metro    57,879.00                      4
# ...       ...        ...        ...           ...                   ...
# 1334   Tier 3  Executive      Metro    59,661.00                      4
# 1335   Tier 1  Executive  Non-Metro    53,714.00                      1
# 1336   Tier 2  Executive  Non-Metro    61,957.00                      1
# 1337   Tier 1  Executive  Non-Metro    53,203.00                      3
# 1338   Tier 3    Manager  Non-Metro    51,820.00                      1
#
#        Graduation marks  Exp (Months)           CTC
# S.No.
# 1                    66            19    71,406.58
# 2                    84            18    68,005.87
# 3                    52            28    76,764.02
# 4                    81            33    82,092.39
# 5                    74            32    73,878.10
# ...                 ...           ...           ...
# 1334                 68            50    69,712.40
# 1335                 67            18    69,298.75
# 1336                 47            18    66,397.77
# 1337                 69            21    64,044.38
# 1338                 47            61    83,346.06
#
# [1338 rows x 8 columns]

# %%
#Displaying the first five datasets
dataset.head()
# Out:
#       College       Role  City type  Previous CTC  Previous job changes  \
# S.No.
# 1      Tier 1    Manager  Non-Metro    55,523.00                      3
# 2      Tier 2  Executive      Metro    57,081.00                      1
# 3      Tier 2  Executive      Metro    60,347.00                      2
# 4      Tier 3  Executive      Metro    49,010.00                      2
# 5      Tier 3  Executive      Metro    57,879.00                      4
#
#        Graduation marks  Exp (Months)           CTC
# S.No.
# 1                    66            19    71,406.58
# 2                    84            18    68,005.87
# 3                    52            28    76,764.02
# 4                    81            33    82,092.39
# 5                    74            32    73,878.10

# %%
#Displaying the summary of this Dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 1 to 1338
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   College               1338 non-null   object
#  1   Role                  1338 non-null   object
#  2   City type             1338 non-null   object
#  3   Previous CTC          1338 non-null   object
#  4   Previous job changes  1338 non-null   int64
#  5   Graduation marks      1338 non-null   int64
#  6   Exp (Months)          1338 non-null   int64
#  7   CTC                   1338 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 94.1+ KB

# %%
#Description of the given dataset
dataset.describe()
# Out:
#        Previous job changes  Graduation marks  Exp (Months)
# count           1338.000000       1338.000000   1338.000000
# mean               2.525411         59.890882     39.207025
# std                1.123502         14.894696     14.049960
# min                1.000000         35.000000     18.000000
# 25%                2.000000         47.000000     27.000000
# 50%                3.000000         60.000000     39.000000
# 75%                4.000000         73.000000     51.000000
# max                4.000000         85.000000     64.000000

# %%
#Checking for null values
dataset.isnull().sum()
# Out:
# College                 0
# Role                    0
# City type               0
# Previous CTC            0
# Previous job changes    0
# Graduation marks        0
# Exp (Months)            0
# CTC                     0
# dtype: int64

# %% [markdown]
# # Here we observe that there are no null values present in our dataset.

# %% [markdown]
# # EXPLORING THE DATASET

# %%
sea.heatmap(dataset.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sea.pairplot(dataset)

# %%
sea.distplot(dataset["CTC"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18408/2794648900.py in <module>
# ----> 1 sea.distplot(dataset["CTC"])
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2634
#    2635     # Make a a 1-d float array
# -> 2636     a = np.asarray(a, float)
#    2637     if a.ndim > 1:
#    2638         a = a.squeeze()
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     855               dtype='datetime64[ns]')
#     856         """
# --> 857         return np.asarray(self._values, dtype)
#     858
#     859     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: '  71,406.58 '

# %%
n = 5
dataset['Exp (Months)'].value_counts()[:n].index.tolist()
# Out:
# [18, 19, 50, 51, 47]

# %%
sea.barplot(x = 'Exp (Months)', y = 'CTC', order = [18,19,50,51,47], data = dataset)
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18408/95120917.py in <module>
#       1 sea.barplot(x = 'Exp (Months)', y = 'CTC', order = [18,19,50,51,47], data = dataset)
# ----> 2 b
#
# NameError: name 'b' is not defined

# %%
n = 5
dataset['Graduation marks'].value_counts()[:n].index.tolist()
# Out:
# [46, 37, 82, 75, 42]

# %%
sea.barplot(x = 'Graduation marks', y = 'CTC', order = [46,37,82,75,42], data = dataset)
# Out:
# <AxesSubplot:xlabel='Graduation marks', ylabel='CTC'>

# %%
#Now load TEST dataset
test = pd.read_csv('Test_data_file.xlsx - Prediction (1).csv')
test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  ...  \
# 0           0         55523                     3                66  ...
# 1           1         57081                     1                84  ...
# 2           1         60347                     2                52  ...
# 3           1         49010                     2                81  ...
# 4           1         57879                     4                74  ...
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN  32438.76192  4659.731658  -832.274662   19359.9439
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23
# 0          NaN          NaN          NaN          NaN          NaN
# 1  4080.577268     0.451593   -29.041071     -3.65235   258.940639
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 24 columns]

# %%
test.columns
# Out:
# Index(['College', 'Role', 'City type', 'College_T1', 'College_T2',
#        'Role_Manager', 'City_Metro', 'previous CTC', 'previous job changes',
#        'Graduation marks', 'Exp', 'Actual CTC', 'Predicted CTC', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23'],
#       dtype='object')

# %%
#Dropping unwanted columns appeared
test.drop(test.columns[14:23], axis=1, inplace=True)
test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#     Actual CTC  Predicted CTC  Unnamed: 13  Unnamed: 23
# 0  71406.57653            NaN          NaN          NaN
# 1  68005.87063            NaN          NaN   258.940639
# 2  76764.02028            NaN          NaN          NaN
# 3  82092.38688            NaN          NaN          NaN
# 4  73878.09773            NaN          NaN          NaN

# %%
del test['Unnamed: 13']
del test['Unnamed: 23']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 13'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18408/1530913972.py in <module>
# ----> 1 del test['Unnamed: 13']
#       2 del test['Unnamed: 23']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3961             # there was no match, this call should raise the appropriate
#    3962             # exception:
# -> 3963             loc = self.axes[-1].get_loc(key)
#    3964             self._mgr = self._mgr.idelete(loc)
#    3965
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Unnamed: 13'

# %%
test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#     Actual CTC  Predicted CTC
# 0  71406.57653            NaN
# 1  68005.87063            NaN
# 2  76764.02028            NaN
# 3  82092.38688            NaN
# 4  73878.09773            NaN

# %%
#We don't have to include 'Role','College' and 'City Type'
del test['Role']
del test['College']
del test['City type']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Role'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18408/3960004513.py in <module>
#       1 #We don't have to include 'Role','College' and 'City Type'
# ----> 2 del test['Role']
#       3 del test['College']
#       4 del test['City type']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3961             # there was no match, this call should raise the appropriate
#    3962             # exception:
# -> 3963             loc = self.axes[-1].get_loc(key)
#    3964             self._mgr = self._mgr.idelete(loc)
#    3965
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Role'

# %%
test.head()
# Out:
#    College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0           1           0             1           0         55523
# 1           0           1             0           1         57081
# 2           0           1             0           1         60347
# 3           0           0             0           1         49010
# 4           0           0             0           1         57879
#
#    previous job changes  Graduation marks  Exp   Actual CTC  Predicted CTC
# 0                     3                66   19  71406.57653            NaN
# 1                     1                84   18  68005.87063            NaN
# 2                     2                52   28  76764.02028            NaN
# 3                     2                81   33  82092.38688            NaN
# 4                     4                74   32  73878.09773            NaN

# %% [markdown]
# #  BUILD LINEAR REGRESSION MODEL

# %%
X = test[['previous CTC','previous job changes','Graduation marks','Exp','College_T1','College_T2','Role_Manager','City_Metro']]
Y = test[['Actual CTC']]

# %%
X
# Out:
#       previous CTC  previous job changes  Graduation marks  Exp  College_T1  \
# 0            55523                     3                66   19           1
# 1            57081                     1                84   18           0
# 2            60347                     2                52   28           0
# 3            49010                     2                81   33           0
# 4            57879                     4                74   32           0
# ...            ...                   ...               ...  ...         ...
# 1333         59661                     4                68   50           0
# 1334         53714                     1                67   18           1
# 1335         61957                     1                47   18           0
# 1336         53203                     3                69   21           1
# 1337         51820                     1                47   61           0
#
#       College_T2  Role_Manager  City_Metro
# 0              0             1           0
# 1              1             0           1
# 2              1             0           1
# 3              0             0           1
# 4              0             0           1
# ...          ...           ...         ...
# 1333           0             0           1
# 1334           0             0           0
# 1335           1             0           0
# 1336           0             0           0
# 1337           0             1           0
#
# [1338 rows x 8 columns]

# %%
Y
# Out:
#        Actual CTC
# 0     71406.57653
# 1     68005.87063
# 2     76764.02028
# 3     82092.38688
# 4     73878.09773
# ...           ...
# 1333  69712.40366
# 1334  69298.75010
# 1335  66397.77069
# 1336  64044.38295
# 1337  83346.06096
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3,random_state = 101)

# %%
#Importing Linear Regression
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # PREDICTING THE CTC

# %%
prediction = lm.predict(X)
test['Predicted CTC'] = prediction
test.head()
# Out:
#    College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0           1           0             1           0         55523
# 1           0           1             0           1         57081
# 2           0           1             0           1         60347
# 3           0           0             0           1         49010
# 4           0           0             0           1         57879
#
#    previous job changes  Graduation marks  Exp   Actual CTC  Predicted CTC
# 0                     3                66   19  71406.57653   85479.353475
# 1                     1                84   18  68005.87063   66555.819928
# 2                     2                52   28  76764.02028   70643.819779
# 3                     2                81   33  82092.38688   67203.839421
# 4                     4                74   32  73878.09773   70681.598118

# %%
#Predicted CTC
prediction
# Out:
# array([[85479.35347546],
#        [66555.81992815],
#        [70643.81977858],
#        ...,
#        [65110.95620656],
#        [65772.64048568],
#        [91010.38463109]])

# %%
#Plotting the predicted CTC with Actual CTC
sea.lmplot(x = 'Actual CTC', y = 'Predicted CTC', data = test, line_kws = {'color': 'red'})

# %%
#Find out the MEAN SQUARE VALUE
from sklearn import metrics
print("Mean Squared Error: ",metrics.mean_squared_error(Y,prediction))
print("Root Mean Squared Error: ",np.sqrt(metrics.mean_squared_error(Y,prediction)))
# Out:
# Mean Squared Error:  61978530.92650955
# Root Mean Squared Error:  7872.644468443215
